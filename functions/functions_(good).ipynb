# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Good)</span></div>

# %% [markdown]
# ## 1 Check, balances and contingencies

# %% [markdown]
# ### 1.1 assert

# %%
x = -1
assert x >= 0, print ("x is becoming negative")
# Out:
# x is becoming negative
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 x = -1
# ----> 2 assert x >= 0, print ("x is becoming negative")
#
# AssertionError: None

# %% [markdown]
# ### 1.2 try-except

# %%
# Your code here

# %% [markdown]
# ## 2 Some loose ends

# %% [markdown]
# ### 2.1 Positional, keyword and default arguments

# %%
# Your code here

# %% [markdown]
# ### 2.2 Docstrings

# %%
# Your code here

# %% [markdown]
# ### 2.3 Function are first class citizens

# %%
# Your code here

# %% [markdown]
# ### 2.4 More unpacking

# %%
# Your code here

# %% [markdown]
# ## Exercise 1 :  A better calculator I

# %%
def divide(x,y):
    assert (y  != 0).all(), "yuan_zhe says ure bad at maths"
    return x/y

x=np.array([36, 34, 44, 76, 27])
y=np.array([64, 66, 56, 24, 73])

divide(x,y)
# Out:
# array([0.5625    , 0.51515152, 0.78571429, 3.16666667, 0.36986301])

# %% [markdown]
# ## Exercise 2 :  A better calculator II

# %%
def divide(x,y):
    try:
        assert (y  != 0).all(), "yuan_zhe says ure bad at maths"
        return x/y
    except:
        print("yuan_zhe says ure bad at maths and coding")
